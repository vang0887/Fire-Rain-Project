# %%
from splinter import Browser
from splinter.exceptions import ElementDoesNotExist
from bs4 import BeautifulSoup

# %%
from sqlalchemy import create_engine, func

# %%
import pandas as pd

# %%
# https://splinter.readthedocs.io/en/latest/drivers/chrome.html
#!which chromedriver

# %%
#Mac
# executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
# browser = Browser('chrome', **executable_path, headless=False)
#Windows
executable_path = {"executable_path": "C:\chromedrv\chromedriver.exe"}
browser = Browser("chrome", **executable_path, headless=False)

# %%
url = 'https://en.wikipedia.org/wiki/List_of_California_wildfires'
browser.visit(url)

# %%
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
print(soup)
# Out:
# <html class="client-js" dir="ltr" lang="en"><head>
# <meta charset="utf-8"/>
# <title>List of California wildfires - Wikipedia</title>
# ...

# %%
table = pd.read_html(url)
large_fire_df= table[0]
large_fire_df
# Out:
#                        Name                         County   Acres  Hectares  \
# 0         Mendocino Complex  Mendocino, Lake,Colusa, Glenn  459123    185800
# 1                    Thomas         Ventura, Santa Barbara  281893    114078
# 2                     Cedar                      San Diego  273246    110579
# 3                      Rush                         Lassen  271911    110038
# 4                       Rim                       Tuolumne  257314    104131
# 5                      Zaca                  Santa Barbara  240207     97208
# 6                      Carr                Shasta, Trinity  229651     92936
# 7                  Matilija                        Ventura  220000     89030
# 8                     Witch                      San Diego  197990     80120
# 9   Klamath Theater Complex                       Siskiyou  192038     77715
# 10              Marble Cone                       Monterey  177866     71980
# ...

# %%
del large_fire_df["Notes"]
large_fire_df
# Out:
#                        Name                         County   Acres  Hectares  \
# 0         Mendocino Complex  Mendocino, Lake,Colusa, Glenn  459123    185800
# 1                    Thomas         Ventura, Santa Barbara  281893    114078
# 2                     Cedar                      San Diego  273246    110579
# 3                      Rush                         Lassen  271911    110038
# 4                       Rim                       Tuolumne  257314    104131
# 5                      Zaca                  Santa Barbara  240207     97208
# 6                      Carr                Shasta, Trinity  229651     92936
# 7                  Matilija                        Ventura  220000     89030
# 8                     Witch                      San Diego  197990     80120
# 9   Klamath Theater Complex                       Siskiyou  192038     77715
# 10              Marble Cone                       Monterey  177866     71980
# ...

# %%
large_fire_df = large_fire_df.rename(columns={"Name": "firename", "County": "county","Acres": "acres", "Hectares":"hectares",
                  "Start date": "startdate","Structures": "structures", "Deaths": "deaths" })

# %%
large_fire_df
# Out:
#                    firename                         county   acres  hectares  \
# 0         Mendocino Complex  Mendocino, Lake,Colusa, Glenn  459123    185800
# 1                    Thomas         Ventura, Santa Barbara  281893    114078
# 2                     Cedar                      San Diego  273246    110579
# 3                      Rush                         Lassen  271911    110038
# 4                       Rim                       Tuolumne  257314    104131
# 5                      Zaca                  Santa Barbara  240207     97208
# 6                      Carr                Shasta, Trinity  229651     92936
# 7                  Matilija                        Ventura  220000     89030
# 8                     Witch                      San Diego  197990     80120
# 9   Klamath Theater Complex                       Siskiyou  192038     77715
# 10              Marble Cone                       Monterey  177866     71980
# ...

# %%
fire_table_html = large_fire_df.to_html()
fire_table_html
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>firename</th>\n      <th>county</th>\n      <th>acres</th>\n      <th>hectares</th>\n      <th>startdate</th>\n      <th>structures</th>\n      <th>deaths</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Mendocino Complex</td>\n      <td>Mendocino, Lake,Colusa, Glenn</td>\n      <td>459123</td>\n      <td>185800</td>\n      <td>July 2018</td>\n      <td>280</td>\n      <td>1</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Thomas</td>\n      <td>Ventura, Santa Barbara</td>\n      <td>281893</td>\n      <td>114078</td>\n      <td>December 2017</td>\n      <td>1063</td>\n      <td>23</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Cedar</td>\n      <td>San Diego</td>\n      <td>273246</td>\n      <td>110579</td>\n      <td>October 2003</td>\n      <td>2820</td>\n      <td>15</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>Rus
# ...

# %%
fire_table_html = fire_table_html.replace("\n","")
fire_table_html
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>firename</th>      <th>county</th>      <th>acres</th>      <th>hectares</th>      <th>startdate</th>      <th>structures</th>      <th>deaths</th>    </tr>  </thead>  <tbody>    <tr>      <th>0</th>      <td>Mendocino Complex</td>      <td>Mendocino, Lake,Colusa, Glenn</td>      <td>459123</td>      <td>185800</td>      <td>July 2018</td>      <td>280</td>      <td>1</td>    </tr>    <tr>      <th>1</th>      <td>Thomas</td>      <td>Ventura, Santa Barbara</td>      <td>281893</td>      <td>114078</td>      <td>December 2017</td>      <td>1063</td>      <td>23</td>    </tr>    <tr>      <th>2</th>      <td>Cedar</td>      <td>San Diego</td>      <td>273246</td>      <td>110579</td>      <td>October 2003</td>      <td>2820</td>      <td>15</td>    </tr>    <tr>      <th>3</th>      <td>Rush</td>      <td>Lassen</td>      <td>271911</td>      <td>110038</td>      <td>August 2012</
# ...

# %%
# engine = create_engine('postgresql://postgres:postgres@localhost:5432/CAWildfire_db')

rds_connection_string = "ryanporrit:Helios007()@localhost:5432/CAWildfire_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.execute("DROP TABLE IF EXISTS largestfires;")

# %%
large_fire_df.to_sql('largestfires', engine)

# %%
engine.execute('ALTER TABLE largestfires ADD PRIMARY KEY (index);')

# %%
rainfall_df = pd.read_csv("Resources/Combined_CA Wildfire_data.csv")

# %%
rainfall_df
# Out:
#          reading  rainfall      fire_name     county
# 0       8/1/1998       0.0  BigBarComplex    Trinity
# 1       8/2/1998       0.0  BigBarComplex    Trinity
# 2       8/3/1998       0.0  BigBarComplex    Trinity
# 3       8/4/1998       0.0  BigBarComplex    Trinity
# 4       8/5/1998       0.0  BigBarComplex    Trinity
# ...          ...       ...            ...        ...
# 6388  11/26/2003       0.0          Cedar  San Diego
# 6389  11/27/2003       0.0          Cedar  San Diego
# 6390  11/28/2003       0.0          Cedar  San Diego
# 6391  11/29/2003       0.0          Cedar  San Diego
# 6392  11/30/2003       0.0          Cedar  San Diego
#
# [6393 rows x 4 columns]

# %%
rainfall_df = rainfall_df.rename(columns={"fire_name": "firename"})
rainfall_df
# Out:
#          reading  rainfall       firename     county
# 0       8/1/1998       0.0  BigBarComplex    Trinity
# 1       8/2/1998       0.0  BigBarComplex    Trinity
# 2       8/3/1998       0.0  BigBarComplex    Trinity
# 3       8/4/1998       0.0  BigBarComplex    Trinity
# 4       8/5/1998       0.0  BigBarComplex    Trinity
# ...          ...       ...            ...        ...
# 6388  11/26/2003       0.0          Cedar  San Diego
# 6389  11/27/2003       0.0          Cedar  San Diego
# 6390  11/28/2003       0.0          Cedar  San Diego
# 6391  11/29/2003       0.0          Cedar  San Diego
# 6392  11/30/2003       0.0          Cedar  San Diego
#
# [6393 rows x 4 columns]

# %%
engine.execute("DROP TABLE IF EXISTS rainfall;")

# %%
rainfall_df.to_sql('rainfall', engine)

# %%
engine.execute('ALTER TABLE rainfall ADD PRIMARY KEY (index);')
